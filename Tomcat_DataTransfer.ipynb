# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from svc_plots import plots
from bokeh.plotting import output_notebook

# %%
##
# make a connection to ES server
# optional arguments are:
#   url: if not specify then 'http://users:cadcusers@elk.canfar.net:9200'
#   timeout: if not specify then 120
#
conn = plots.Init(timeout = 900).connect()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a22d410d-b2f4-4ec8-8683-3a8f90681c91">Loading BokehJS ...</span>
#     </div>

# %%
# %autoreload
##
# averge duration of transfer_ws, data_ws, vospace_ws
# for each service, put and get
#
plots.tomcat_datatransfer_timeevo(conn, "logs-tomcat")
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ef572bf6-8d73-498f-80e1-5e1829e75e19"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
# %autoreload
##
# average transfer_ws put rate from batch.canfar.net as vbar
# vs
# number of batch processing jobs as red line
#
plots.tomcat_transfer_rate_batch_dot_canfar_dot_net_vs_num_batch_jobs(conn, "logs-tomcat")
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c6d9d5fe-a48a-4a72-80ee-de112b2abf4f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
# %autoreload
##
# four pie charts:
#             in size   in number of files
# downloads    pie1      pie2
# 
# uploads     pie3      pie4
#
# for transfer_ws
#
plots.tomcat_datatransfer_num_n_size(conn, "logs-tomcat")
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4252dbe0-7c93-41d1-ba49-4521b3544063"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
# %autoreload
##
# four pie charts:
#             data_ws        vospace_ws
# downloads    pie1           pie2
# 
# uploads     pie3            pie4
#
# for number of events
#
plots.tomcat_data_vos_num_events(conn, "logs-tomcat")
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fd4b7364-ec84-4cf0-bfd3-279237648521"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
# %autoreload
##
# box chart for download and upload rates over time, grouped by CC-CADC-NRC-Others domain
# 75%-50%-25% respectively
#
plots.tomcat_dl_rate_past_tw_yrs(conn, "logs-tomcat")
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f0ad2ac9-7e7f-47f5-a130-6383f8b1e601"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
# %autoreload
##
# failure rate for transfer_ws, download and upload
#
plots.tomcat_f_rate(conn, "logs-tomcat")
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a109b167-0567-4a7d-9fd5-584b910a3ec6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
from svc_plots import tomcat_old

# %%
##
# number of files in M
# size in TB
#
tomcat_old.fig7(conn, "logs-tomcat")
# Out:
# now-1M
# Empty DataFrame
# Columns: []
# Index: []
# now-2M
#         Unique File  Unique File Size
# CADC       0.166677          0.630320
# CC         0.828166         32.794557
# NRC        0.034217          0.109898
# Others     0.682446         10.450392
# now-3M
#         Unique File  Unique File Size
# CADC       0.330496          5.553237
# CC         1.043118         40.030171
# NRC        0.033134          0.083244
# Others     0.563725          4.924330
# now-4M
#         Unique File  Unique File Size
# CADC       0.492731          0.303709
# CC         1.565639         57.502010
# NRC        0.032626          0.062703
# Others     0.530926          6.380574
# now-5M
#         Unique File  Unique File Size
# CADC       0.222694          0.475077
# CC         1.376779         45.064662
# NRC        0.000316          0.016026
# Others     0.532983          7.030805
# now-6M
#         Unique File  Unique File Size
# CADC       0.659509          0.346098
# ...
